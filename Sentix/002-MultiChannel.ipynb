# %%
import os
import random
from nltk.corpus import stopwords
from nltk import word_tokenize
from string import punctuation
import pickle
import numpy as np

# %%
stop_words = stopwords.words('english')

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
translator = str.maketrans('', '', punctuation)
a = 'salam$%^'
a.translate(translator)
# Out:
# 'salam'

# %%
negative_documents = []
max_len_negative = 0
for file in os.listdir('data/neg'):
    with open('data/neg/' + file) as f:
        text = f.read()
        tokens = word_tokenize(text)
        translator = str.maketrans('', '', punctuation)
        tokens = [w.translate(translator) for w in tokens]
        tokens = [w for w in tokens if not w in stop_words]
        negative_documents.append(' '.join(tokens))
        if len(tokens) > max_len_negative:
            max_len_negative = len(tokens)
len(negative_documents)
# Out:
# 1000

# %%
max_len_negative
# Out:
# 1400

# %%
positive_documents = []
max_len_positive = 0
for file in os.listdir('data/pos'):
    with open('data/pos/' + file) as f:
        text = f.read()
        tokens = word_tokenize(text)
        translator = str.maketrans('', '', punctuation)
        tokens = [w.translate(translator) for w in tokens]
        tokens = [w for w in tokens if not w in stop_words]
        positive_documents.append(' '.join(tokens))
        if len(tokens) > max_len_positive:
            max_len_positive = len(tokens)
len(positive_documents)
# Out:
# 1000

# %%
max_len_positive
# Out:
# 1693

# %%
max_len = max(max_len_negative, max_len_positive)
max_len
# Out:
# 1693

# %%
random.shuffle(negative_documents)

# %%
random.shuffle(positive_documents)

# %%
X_train = negative_documents[:800] + positive_documents[:800]

# %%
len(X_train)
# Out:
# 1600

# %%
y_train = [0 for _ in range(800)] + [1 for _ in range(800)]

# %%
len(y_train)
# Out:
# 1600

# %%
X_test = negative_documents[800:] + positive_documents[800:]

# %%
len(X_test)
# Out:
# 400

# %%
y_test = [0 for _ in range(200)] + [1 for _ in range(200)]

# %%
len(y_test)
# Out:
# 400

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv1D, MaxPool1D, Embedding, Dropout
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import concatenate

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
tokenizer

# %%
with open('tokenizer.h5', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
tokenizer.word_index
# Out:
# {'film': 1,
#  'nt': 2,
#  'movie': 3,
#  'one': 4,
#  'like': 5,
#  'even': 6,
#  'good': 7,
#  'time': 8,
#  'would': 9,
#  'story': 10,
#  'much': 11,
#  'character': 12,
#  'also': 13,
#  'get': 14,
#  'characters': 15,
#  'two': 16,
#  'first': 17,
#  'see': 18,
#  'well': 19,
#  'way': 20,
#  'could': 21,
#  'make': 22,
#  'really': 23,
#  'films': 24,
#  'people': 25,
#  'little': 26,
#  'plot': 27,
#  'life': 28,
#  'scene': 29,
#  'bad': 30,
#  'never': 31,
#  'man': 32,
#  'new': 33,
#  'best': 34,
#  'many': 35,
#  'scenes': 36,
#  'know': 37,
#  'movies': 38,
#  'love': 39,
#  'another': 40,
#  'great': 41,
#  'director': 42,
#  'something': 43,
#  'action': 44,
#  'end': 45,
#  'us': 46,
#  'go': 47,
#  'seems': 48,
#  'made': 49,
#  'back': 50,
#  'world': 51,
#  'however': 52,
#  'still': 53,
#  'work': 54,
#  'big': 55,
#  'makes': 56,
#  'every': 57,
#  'audience': 58,
#  'though': 59,
#  'better': 60,
#  'around': 61,
#  'enough': 62,
#  'real': 63,
#  'seen': 64,
#  'take': 65,
#  'performance': 66,
#  'role': 67,
#  'going': 68,
#  'gets': 69,
#  'may': 70,
#  'say': 71,
#  'almost': 72,
#  'think': 73,
#  'last': 74,
#  'actually': 75,
#  'look': 76,
#  'funny': 77,
#  'things': 78,
#  'played': 79,
#  'comedy': 80,
#  'nothing': 81,
#  'although': 82,
#  'years': 83,
#  'thing': 84,
#  'fact': 85,
#  'script': 86,
#  'since': 87,
#  'john': 88,
#  'right': 89,
#  'come': 90,
#  'find': 91,
#  'long': 92,
#  'young': 93,
#  'old': 94,
#  'cast': 95,
#  'plays': 96,
#  'comes': 97,
#  'original': 98,
#  'star': 99,
#  'ever': 100,
#  'show': 101,
#  'least': 102,
#  'lot': 103,
#  'year': 104,
#  'acting': 105,
#  'actors': 106,
#  'without': 107,
#  'part': 108,
#  'quite': 109,
#  'point': 110,
#  'course': 111,
#  'takes': 112,
#  'guy': 113,
#  'goes': 114,
#  'interesting': 115,
#  'ca': 116,
#  'minutes': 117,
#  'away': 118,
#  'screen': 119,
#  'family': 120,
#  'three': 121,
#  'far': 122,
#  'might': 123,
#  'place': 124,
#  'effects': 125,
#  'watch': 126,
#  'rather': 127,
#  'yet': 128,
#  'anything': 129,
#  'day': 130,
#  'must': 131,
#  'seem': 132,
#  'hollywood': 133,
#  'picture': 134,
#  'fun': 135,
#  'bit': 136,
#  'series': 137,
#  'always': 138,
#  'special': 139,
#  'times': 140,
#  'making': 141,
#  'wife': 142,
#  'want': 143,
#  'actor': 144,
#  'give': 145,
#  'kind': 146,
#  'instead': 147,
#  'trying': 148,
#  'set': 149,
#  'woman': 150,
#  'men': 151,
#  'everything': 152,
#  'job': 153,
#  'probably': 154,
#  'becomes': 155,
#  'sense': 156,
#  'american': 157,
#  'given': 158,
#  'home': 159,
#  'dialogue': 160,
#  'along': 161,
#  'sure': 162,
#  'high': 163,
#  'become': 164,
#  'together': 165,
#  'help': 166,
#  'pretty': 167,
#  'everyone': 168,
#  'black': 169,
#  'hard': 170,
#  'whole': 171,
#  'money': 172,
#  'watching': 173,
#  'gives': 174,
#  'got': 175,
#  'father': 176,
#  'especially': 177,
#  'wants': 178,
#  'death': 179,
#  'perhaps': 180,
#  'looking': 181,
#  'feel': 182,
#  'sex': 183,
#  'next': 184,
#  'done': 185,
#  'city': 186,
#  'less': 187,
#  'whose': 188,
#  'moments': 189,
#  'looks': 190,
#  'play': 191,
#  'ending': 192,
#  'horror': 193,
#  'rest': 194,
#  'performances': 195,
#  'james': 196,
#  'music': 197,
#  'different': 198,
#  'anyone': 199,
#  'reason': 200,
#  'completely': 201,
#  'shows': 202,
#  'let': 203,
#  'michael': 204,
#  'simply': 205,
#  'several': 206,
#  'evil': 207,
#  'alien': 208,
#  'night': 209,
#  'couple': 210,
#  'entire': 211,
#  'mind': 212,
#  '2': 213,
#  'put': 214,
#  'human': 215,
#  'humor': 216,
#  'getting': 217,
#  'left': 218,
#  'turns': 219,
#  'line': 220,
#  'someone': 221,
#  'girl': 222,
#  'problem': 223,
#  'use': 224,
#  'friend': 225,
#  'begins': 226,
#  'either': 227,
#  'main': 228,
#  'found': 229,
#  'unfortunately': 230,
#  'true': 231,
#  'lost': 232,
#  'small': 233,
#  'half': 234,
#  'idea': 235,
#  'final': 236,
#  'case': 237,
#  'tries': 238,
#  'friends': 239,
#  'else': 240,
#  'group': 241,
#  'stars': 242,
#  'tv': 243,
#  'used': 244,
#  'wrong': 245,
#  'believe': 246,
#  'house': 247,
#  'later': 248,
#  'name': 249,
#  'written': 250,
#  'called': 251,
#  'mother': 252,
#  'thought': 253,
#  'certainly': 254,
#  'soon': 255,
#  'comic': 256,
#  'david': 257,
#  'said': 258,
#  'sequence': 259,
#  'town': 260,
#  'often': 261,
#  'maybe': 262,
#  'named': 263,
#  'school': 264,
#  'finally': 265,
#  'relationship': 266,
#  'playing': 267,
#  'able': 268,
#  'head': 269,
#  'hand': 270,
#  'keep': 271,
#  'perfect': 272,
#  'based': 273,
#  'works': 274,
#  'summer': 275,
#  'second': 276,
#  'turn': 277,
#  'past': 278,
#  'despite': 279,
#  'including': 280,
#  'dark': 281,
#  'seeing': 282,
#  'behind': 283,
#  'dead': 284,
#  'book': 285,
#  'run': 286,
#  'fight': 287,
#  'finds': 288,
#  'car': 289,
#  'supposed': 290,
#  'lives': 291,
#  'tell': 292,
#  'days': 293,
#  'running': 294,
#  'directed': 295,
#  'person': 296,
#  'moment': 297,
#  'need': 298,
#  'lines': 299,
#  'game': 300,
#  'children': 301,
#  'entertaining': 302,
#  'camera': 303,
#  'shot': 304,
#  'kids': 305,
#  'nice': 306,
#  'side': 307,
#  'try': 308,
#  'war': 309,
#  'worth': 310,
#  'live': 311,
#  'start': 312,
#  'boy': 313,
#  'major': 314,
#  'full': 315,
#  'hour': 316,
#  'mr': 317,
#  'matter': 318,
#  'starts': 319,
#  'joe': 320,
#  'face': 321,
#  'earth': 322,
#  'worst': 323,
#  'son': 324,
#  'team': 325,
#  'exactly': 326,
#  'style': 327,
#  'problems': 328,
#  'version': 329,
#  'scream': 330,
#  'daughter': 331,
#  'example': 332,
#  'order': 333,
#  'care': 334,
#  'nearly': 335,
#  'sequences': 336,
#  'kevin': 337,
#  'others': 338,
#  'screenplay': 339,
#  'violence': 340,
#  'review': 341,
#  'beautiful': 342,
#  'upon': 343,
#  'throughout': 344,
#  'space': 345,
#  'short': 346,
#  'video': 347,
#  'fine': 348,
#  'early': 349,
#  'simple': 350,
#  'drama': 351,
#  'known': 352,
#  'already': 353,
#  'direction': 354,
#  'title': 355,
#  'opening': 356,
#  'kill': 357,
#  'robert': 358,
#  'jackie': 359,
#  'hit': 360,
#  'act': 361,
#  'knows': 362,
#  'white': 363,
#  'top': 364,
#  'jack': 365,
#  'production': 366,
#  'obvious': 367,
#  'peter': 368,
#  'planet': 369,
#  'sort': 370,
#  'save': 371,
#  'saw': 372,
#  'classic': 373,
#  'women': 374,
#  'lee': 375,
#  'jokes': 376,
#  'york': 377,
#  'boring': 378,
#  'beginning': 379,
#  'roles': 380,
#  'guys': 381,
#  'deep': 382,
#  'killer': 383,
#  'eyes': 384,
#  'room': 385,
#  'truly': 386,
#  'body': 387,
#  'attempt': 388,
#  'disney': 389,
#  'supporting': 390,
#  'sometimes': 391,
#  'ends': 392,
#  'wonder': 393,
#  'lead': 394,
#  'stupid': 395,
#  'possible': 396,
#  'child': 397,
#  'extremely': 398,
#  'strong': 399,
#  'heart': 400,
#  'wo': 401,
#  'says': 402,
#  'coming': 403,
#  'brother': 404,
#  'ship': 405,
#  'involving': 406,
#  'worse': 407,
#  'level': 408,
#  'voice': 409,
#  'mostly': 410,
#  'genre': 411,
#  'yes': 412,
#  'particularly': 413,
#  'happens': 414,
#  'question': 415,
#  'police': 416,
#  'aliens': 417,
#  'tom': 418,
#  'novel': 419,
#  'eventually': 420,
#  'tells': 421,
#  'husband': 422,
#  'falls': 423,
#  'girls': 424,
#  'four': 425,
#  'manages': 426,
#  'quickly': 427,
#  'hours': 428,
#  'career': 429,
#  'future': 430,
#  'emotional': 431,
#  'meet': 432,
#  'sets': 433,
#  'power': 434,
#  'five': 435,
#  'hero': 436,
#  'sound': 437,
#  'appears': 438,
#  'romantic': 439,
#  'involved': 440,
#  'fall': 441,
#  'murder': 442,
#  'close': 443,
#  'lack': 444,
#  'hope': 445,
#  'stop': 446,
#  'piece': 447,
#  'none': 448,
#  'leads': 449,
#  'note': 450,
#  'dog': 451,
#  'guess': 452,
#  'mission': 453,
#  'result': 454,
#  'material': 455,
#  'mean': 456,
#  'elements': 457,
#  'thriller': 458,
#  'dr': 459,
#  'chance': 460,
#  'taken': 461,
#  'smith': 462,
#  'enjoy': 463,
#  'taking': 464,
#  'hell': 465,
#  'usually': 466,
#  'obviously': 467,
#  'laughs': 468,
#  'television': 469,
#  'forced': 470,
#  'among': 471,
#  'computer': 472,
#  'needs': 473,
#  'paul': 474,
#  'killed': 475,
#  '1': 476,
#  'george': 477,
#  'god': 478,
#  'de': 479,
#  'attention': 480,
#  'history': 481,
#  'interest': 482,
#  'living': 483,
#  'talk': 484,
#  'number': 485,
#  'feeling': 486,
#  'king': 487,
#  'fans': 488,
#  'seemed': 489,
#  'laugh': 490,
#  'basically': 491,
#  'deal': 492,
#  'single': 493,
#  'talent': 494,
#  'except': 495,
#  'oscar': 496,
#  'easy': 497,
#  'science': 498,
#  'experience': 499,
#  'word': 500,
#  'late': 501,
#  'poor': 502,
#  'bring': 503,
#  'theater': 504,
#  'impressive': 505,
#  'viewer': 506,
#  'features': 507,
#  'success': 508,
#  'attempts': 509,
#  'feels': 510,
#  'tale': 511,
#  'fiction': 512,
#  'cool': 513,
#  'robin': 514,
#  'chris': 515,
#  'whether': 516,
#  'america': 517,
#  'words': 518,
#  'battle': 519,
#  'girlfriend': 520,
#  'crew': 521,
#  'within': 522,
#  'sequel': 523,
#  'release': 524,
#  'recent': 525,
#  'premise': 526,
#  'apparently': 527,
#  'across': 528,
#  'somehow': 529,
#  'entertainment': 530,
#  'using': 531,
#  'leave': 532,
#  'easily': 533,
#  'feature': 534,
#  'batman': 535,
#  'score': 536,
#  'wild': 537,
#  'told': 538,
#  'happen': 539,
#  'went': 540,
#  'crime': 541,
#  'form': 542,
#  'stuff': 543,
#  'wonderful': 544,
#  'alone': 545,
#  'surprise': 546,
#  '3': 547,
#  'serious': 548,
#  'important': 549,
#  'expect': 550,
#  'released': 551,
#  'van': 552,
#  'presence': 553,
#  'parents': 554,
#  'call': 555,
#  'ways': 556,
#  'williams': 557,
#  'giving': 558,
#  'working': 559,
#  'ben': 560,
#  'events': 561,
#  'happy': 562,
#  'former': 563,
#  'art': 564,
#  'return': 565,
#  'complete': 566,
#  'change': 567,
#  'meets': 568,
#  'popular': 569,
#  'difficult': 570,
#  'certain': 571,
#  'general': 572,
#  'parts': 573,
#  'hilarious': 574,
#  'william': 575,
#  'brothers': 576,
#  'brings': 577,
#  'oh': 578,
#  'quality': 579,
#  'turned': 580,
#  'figure': 581,
#  'kid': 582,
#  'reality': 583,
#  'suspense': 584,
#  'effective': 585,
#  'sexual': 586,
#  'annoying': 587,
#  'flick': 588,
#  'previous': 589,
#  'wars': 590,
#  'ago': 591,
#  'middle': 592,
#  'decides': 593,
#  'bill': 594,
#  'personal': 595,
#  'business': 596,
#  'carter': 597,
#  'strange': 598,
#  'familiar': 599,
#  'credits': 600,
#  'similar': 601,
#  'uses': 602,
#  'anyway': 603,
#  'remember': 604,
#  'project': 605,
#  'company': 606,
#  'gone': 607,
#  'surprisingly': 608,
#  'intelligent': 609,
#  'blood': 610,
#  'came': 611,
#  'jim': 612,
#  'filmmakers': 613,
#  'runs': 614,
#  'somewhat': 615,
#  '4': 616,
#  'powerful': 617,
#  'local': 618,
#  'present': 619,
#  'opens': 620,
#  'writer': 621,
#  'towards': 622,
#  'shots': 623,
#  'villain': 624,
#  'dramatic': 625,
#  'visual': 626,
#  'die': 627,
#  'situation': 628,
#  'questions': 629,
#  'definitely': 630,
#  'harry': 631,
#  'potential': 632,
#  'usual': 633,
#  'party': 634,
#  'murphy': 635,
#  'ones': 636,
#  'jones': 637,
#  'light': 638,
#  'successful': 639,
#  'writing': 640,
#  'third': 641,
#  'seriously': 642,
#  'mystery': 643,
#  'romance': 644,
#  'sam': 645,
#  'due': 646,
#  'trek': 647,
#  'begin': 648,
#  'secret': 649,
#  'cut': 650,
#  'felt': 651,
#  'leaving': 652,
#  'clear': 653,
#  'beyond': 654,
#  'cop': 655,
#  'nature': 656,
#  'office': 657,
#  'leaves': 658,
#  'bunch': 659,
#  'smart': 660,
#  'took': 661,
#  'cameron': 662,
#  'type': 663,
#  'read': 664,
#  'prison': 665,
#  'martin': 666,
#  'absolutely': 667,
#  'doubt': 668,
#  'richard': 669,
#  'escape': 670,
#  'huge': 671,
#  'subject': 672,
#  'unlike': 673,
#  'add': 674,
#  'latest': 675,
#  'straight': 676,
#  'following': 677,
#  'decent': 678,
#  'rich': 679,
#  'starring': 680,
#  'scott': 681,
#  'means': 682,
#  'mars': 683,
#  'allen': 684,
#  'large': 685,
#  'scary': 686,
#  'excellent': 687,
#  'effect': 688,
#  'ryan': 689,
#  'actress': 690,
#  'talking': 691,
#  'plan': 692,
#  'heard': 693,
#  'inside': 694,
#  'thinking': 695,
#  'follow': 696,
#  '10': 697,
#  'brilliant': 698,
#  'mess': 699,
#  'near': 700,
#  'cinema': 701,
#  'create': 702,
#  'follows': 703,
#  'move': 704,
#  'overall': 705,
#  'clever': 706,
#  'amazing': 707,
#  'motion': 708,
#  'impossible': 709,
#  'chase': 710,
#  'saying': 711,
#  'message': 712,
#  'force': 713,
#  'created': 714,
#  'chan': 715,
#  'giant': 716,
#  'break': 717,
#  'stay': 718,
#  'country': 719,
#  'audiences': 720,
#  'million': 721,
#  'trouble': 722,
#  'learn': 723,
#  'married': 724,
#  'realize': 725,
#  'water': 726,
#  'godzilla': 727,
#  'liked': 728,
#  'age': 729,
#  'ultimately': 730,
#  'eddie': 731,
#  'moving': 732,
#  'viewers': 733,
#  'park': 734,
#  'points': 735,
#  'bob': 736,
#  'agent': 737,
#  'bruce': 738,
#  'understand': 739,
#  'predictable': 740,
#  'merely': 741,
#  'fails': 742,
#  'west': 743,
#  'appear': 744,
#  'filled': 745,
#  'favorite': 746,
#  'master': 747,
#  'enjoyable': 748,
#  'happened': 749,
#  'immediately': 750,
#  'wanted': 751,
#  'exciting': 752,
#  'dream': 753,
#  'otherwise': 754,
#  'pay': 755,
#  'slow': 756,
#  'r': 757,
#  'situations': 758,
#  'simon': 759,
#  'stories': 760,
#  'brought': 761,
#  'fan': 762,
#  'offers': 763,
#  'frank': 764,
#  'neither': 765,
#  'likely': 766,
#  'showing': 767,
#  'tim': 768,
#  'ideas': 769,
#  'solid': 770,
#  'memorable': 771,
#  'atmosphere': 772,
#  'english': 773,
#  'ten': 774,
#  'actual': 775,
#  'dumb': 776,
#  'studio': 777,
#  'mark': 778,
#  'government': 779,
#  'constantly': 780,
#  'perfectly': 781,
#  'l': 782,
#  'stone': 783,
#  'e': 784,
#  'political': 785,
#  'animated': 786,
#  'particular': 787,
#  'biggest': 788,
#  'control': 789,
#  'effort': 790,
#  'credit': 791,
#  'state': 792,
#  'entirely': 793,
#  'purpose': 794,
#  'mary': 795,
#  'red': 796,
#  'various': 797,
#  'typical': 798,
#  'spend': 799,
#  'aspect': 800,
#  'cold': 801,
#  'silly': 802,
#  'bond': 803,
#  'army': 804,
#  'humans': 805,
#  'truth': 806,
#  'musical': 807,
#  'gave': 808,
#  'today': 809,
#  'woody': 810,
#  'law': 811,
#  'spent': 812,
#  'nick': 813,
#  'truman': 814,
#  'fear': 815,
#  'tension': 816,
#  'suddenly': 817,
#  'earlier': 818,
#  'slightly': 819,
#  'focus': 820,
#  'hands': 821,
#  'rating': 822,
#  'ii': 823,
#  'ask': 824,
#  'open': 825,
#  'element': 826,
#  'max': 827,
#  'wedding': 828,
#  'society': 829,
#  'british': 830,
#  'totally': 831,
#  'indeed': 832,
#  'subplot': 833,
#  'view': 834,
#  'sit': 835,
#  'ability': 836,
#  'complex': 837,
#  'whatever': 838,
#  'members': 839,
#  'killing': 840,
#  'queen': 841,
#  'cinematography': 842,
#  'setting': 843,
#  'class': 844,
#  'box': 845,
#  'female': 846,
#  'jerry': 847,
#  'convincing': 848,
#  'dull': 849,
#  'amusing': 850,
#  'moves': 851,
#  'fast': 852,
#  'greatest': 853,
#  'wait': 854,
#  'animation': 855,
#  'waste': 856,
#  'terrible': 857,
#  'college': 858,
#  'miss': 859,
#  'carry': 860,
#  'lots': 861,
#  'private': 862,
#  'steve': 863,
#  'background': 864,
#  'steven': 865,
#  'approach': 866,
#  'eye': 867,
#  'leader': 868,
#  'beauty': 869,
#  'mike': 870,
#  'soundtrack': 871,
#  'free': 872,
#  'subtle': 873,
#  'recently': 874,
#  'sweet': 875,
#  'decide': 876,
#  'monster': 877,
#  'titanic': 878,
#  'hold': 879,
#  'expected': 880,
#  'appearance': 881,
#  'fairly': 882,
#  'shown': 883,
#  'drug': 884,
#  'chemistry': 885,
#  'carrey': 886,
#  'stand': 887,
#  'thinks': 888,
#  'awful': 889,
#  'cheap': 890,
#  'joke': 891,
#  'hate': 892,
#  'list': 893,
#  'minor': 894,
#  'language': 895,
#  'reasons': 896,
#  'common': 897,
#  'flat': 898,
#  'casting': 899,
#  'plenty': 900,
#  'keeps': 901,
#  'cinematic': 902,
#  'theme': 903,
#  'depth': 904,
#  'club': 905,
#  'talented': 906,
#  'ridiculous': 907,
#  'teen': 908,
#  'air': 909,
#  'images': 910,
#  'longer': 911,
#  'partner': 912,
#  'screenwriter': 913,
#  'tone': 914,
#  'race': 915,
#  'front': 916,
#  'believable': 917,
#  'asks': 918,
#  'rock': 919,
#  'outside': 920,
#  'wish': 921,
#  'wrote': 922,
#  'baby': 923,
#  'gun': 924,
#  'violent': 925,
#  'okay': 926,
#  'president': 927,
#  'french': 928,
#  'sister': 929,
#  'incredibly': 930,
#  'budget': 931,
#  'stands': 932,
#  'scifi': 933,
#  'key': 934,
#  'remains': 935,
#  'clearly': 936,
#  'development': 937,
#  'brief': 938,
#  'j': 939,
#  'energy': 940,
#  'sight': 941,
#  'event': 942,
#  'disaster': 943,
#  'charm': 944,
#  'somewhere': 945,
#  'member': 946,
#  'sounds': 947,
#  'meanwhile': 948,
#  'conclusion': 949,
#  'island': 950,
#  'la': 951,
#  'amount': 952,
#  'pull': 953,
#  'willis': 954,
#  'sean': 955,
#  'knew': 956,
#  'imagine': 957,
#  'fire': 958,
#  'grace': 959,
#  'b': 960,
#  'onto': 961,
#  'detective': 962,
#  'writers': 963,
#  'choice': 964,
#  'boss': 965,
#  'dreams': 966,
#  'opportunity': 967,
#  'minute': 968,
#  'jackson': 969,
#  'caught': 970,
#  'provide': 971,
#  'trailer': 972,
#  'thus': 973,
#  'critics': 974,
#  'blade': 975,
#  'realistic': 976,
#  'boys': 977,
#  'led': 978,
#  'modern': 979,
#  'possibly': 980,
#  '1998': 981,
#  'song': 982,
#  'basic': 983,
#  'provides': 984,
#  'vampire': 985,
#  'worked': 986,
#  'road': 987,
#  'ride': 988,
#  'fox': 989,
#  'telling': 990,
#  'consider': 991,
#  'puts': 992,
#  'six': 993,
#  'seemingly': 994,
#  'contains': 995,
#  'etc': 996,
#  'hear': 997,
#  'famous': 998,
#  'pace': 999,
#  'tough': 1000,
#  ...}

# %%
vocab_len = len(tokenizer.word_index) + 1

# %%
vocab_len
# Out:
# 40616

# %%
encoded = tokenizer.texts_to_sequences(X_train)

# %%
encoded[0]
# Out:
# [1338,
#  103,
#  434,
#  133,
#  57,
#  104,
#  2605,
#  24,
#  49,
#  11424,
#  58,
#  787,
#  3520,
#  211,
#  1151,
#  3058,
#  277,
#  3769,
#  2355,
#  1515,
#  18197,
#  270,
#  1304,
#  350,
#  22,
#  1,
#  55,
#  249,
#  93,
#  144,
#  690,
#  183,
#  1239,
#  674,
#  163,
#  264,
#  3145,
#  507,
#  168,
#  4598,
#  8504,
#  6160,
#  905,
#  8505,
#  350,
#  266,
#  1540,
#  986,
#  1371,
#  117,
#  798,
#  1151,
#  480,
#  5546,
#  2825,
#  2606,
#  108,
#  3058,
#  856,
#  15038,
#  172,
#  72,
#  1,
#  149,
#  3145,
#  2826,
#  2177,
#  15039,
#  334,
#  1806,
#  23837,
#  579,
#  447,
#  2178,
#  646,
#  31,
#  4376,
#  675,
#  1,
#  42,
#  11425,
#  18198,
#  2178,
#  4794,
#  11426,
#  2533,
#  2261,
#  6892,
#  2306,
#  2827,
#  481,
#  2125,
#  3146,
#  140,
#  595,
#  1807,
#  12891,
#  7897,
#  657,
#  11,
#  12892,
#  1780,
#  28,
#  81,
#  178,
#  2534,
#  47,
#  1321,
#  191,
#  7898,
#  67,
#  2125,
#  1440,
#  3647,
#  109,
#  1099,
#  1024,
#  1322,
#  3335,
#  23838,
#  780,
#  23839,
#  4794,
#  54,
#  124,
#  225,
#  8506,
#  2975,
#  3521,
#  18199,
#  1262,
#  4042,
#  88,
#  1516,
#  7368,
#  16,
#  12893,
#  193,
#  343,
#  2356,
#  1113,
#  17,
#  3647,
#  15040,
#  657,
#  2976,
#  2534,
#  52,
#  87,
#  1,
#  3147,
#  1151,
#  58,
#  26,
#  5032,
#  12,
#  1540,
#  754,
#  115,
#  2977,
#  5547,
#  522,
#  16,
#  117,
#  4794,
#  2307,
#  1321,
#  467,
#  1321,
#  3647,
#  1056,
#  163,
#  264,
#  2607,
#  164,
#  3522,
#  2534,
#  163,
#  264,
#  23840,
#  5826,
#  844,
#  1085,
#  4,
#  15039,
#  73,
#  298,
#  6,
#  648,
#  1210,
#  23841,
#  628,
#  100,
#  9317,
#  18200,
#  3,
#  2409,
#  4794,
#  148,
#  91,
#  28,
#  31,
#  978,
#  163,
#  264,
#  18201,
#  2410,
#  36,
#  101,
#  46,
#  11,
#  12894,
#  386,
#  438,
#  4795,
#  987,
#  2608,
#  1114,
#  366,
#  15,
#  744,
#  22,
#  163,
#  264,
#  36,
#  1441,
#  2750,
#  115,
#  1070,
#  740,
#  39,
#  760,
#  1211,
#  4199,
#  2907,
#  1169,
#  204,
#  12895,
#  101,
#  4794,
#  23,
#  16,
#  25,
#  4,
#  387,
#  13,
#  1152,
#  404,
#  1442,
#  1443,
#  257,
#  2262,
#  97,
#  33,
#  229,
#  28,
#  6,
#  1915,
#  1339,
#  29,
#  2751,
#  5827,
#  216,
#  229,
#  1,
#  75,
#  109,
#  850,
#  798,
#  1151,
#  24,
#  12896,
#  315,
#  586,
#  12897,
#  18202,
#  216,
#  4,
#  29,
#  787,
#  507,
#  571,
#  15041,
#  6498,
#  406,
#  9318,
#  9319,
#  667,
#  4200,
#  376,
#  676,
#  1305,
#  163,
#  264,
#  216,
#  199,
#  100,
#  163,
#  264,
#  1323,
#  463,
#  53,
#  15039,
#  5033,
#  1340,
#  444,
#  579,
#  3,
#  677,
#  3336,
#  163,
#  264,
#  3,
#  1195,
#  97,
#  572,
#  105,
#  6,
#  407,
#  3336,
#  15042,
#  2977,
#  1,
#  1,
#  237,
#  2533,
#  2261,
#  667,
#  2040,
#  126,
#  2411,
#  191,
#  12,
#  16,
#  2752,
#  169,
#  363,
#  10266,
#  82,
#  36,
#  250,
#  787,
#  6161,
#  5548,
#  48,
#  879,
#  1412,
#  344,
#  119,
#  8,
#  4,
#  110,
#  545,
#  367,
#  39,
#  482,
#  6499,
#  4796,
#  880,
#  1212,
#  408,
#  87,
#  4,
#  1169,
#  31,
#  48,
#  14,
#  5548,
#  2535,
#  56,
#  8507,
#  754,
#  7,
#  66,
#  677,
#  2261,
#  6893,
#  2975,
#  3521,
#  2355,
#  209,
#  311,
#  48,
#  1413,
#  267,
#  10267,
#  12,
#  4,
#  2826,
#  5034,
#  480,
#  58,
#  205,
#  3770,
#  2609,
#  3433,
#  2080,
#  18202,
#  29,
#  4,
#  678,
#  2179,
#  4,
#  41,
#  66,
#  6162,
#  754,
#  2308,
#  1,
#  257,
#  2262,
#  330,
#  112,
#  159,
#  4599,
#  268,
#  887,
#  1952,
#  66,
#  667,
#  1444,
#  698,
#  105,
#  3771,
#  1057,
#  12,
#  69,
#  65,
#  18203,
#  4,
#  19,
#  185,
#  573,
#  31,
#  4376,
#  4377,
#  23842,
#  663,
#  447,
#  54,
#  667,
#  574,
#  418,
#  1916,
#  1517,
#  7369,
#  360,
#  5272,
#  596,
#  31,
#  4376,
#  1595,
#  1,
#  34,
#  740,
#  27,
#  164,
#  9320,
#  133,
#  7370,
#  126,
#  8,
#  1,
#  1213,
#  105,
#  30,
#  4,
#  1953,
#  553,
#  257,
#  2262,
#  674,
#  638,
#  230,
#  1541,
#  220,
#  3,
#  508,
#  1338,
#  755,
#  18,
#  2178]

# %%
padded = pad_sequences(encoded, maxlen=max_len, padding='post')

# %%
padded.shape
# Out:
# (1600, 1693)

# %%
input1 = Input(shape=(max_len,))
embedding1 = Embedding(vocab_len, 100)(input1)
conv1 = Conv1D(filters=32, kernel_size=4, activation='relu')(embedding1)
drop1 = Dropout(0.5)(conv1)
pool1 = MaxPool1D(pool_size=2)(drop1)
flat1 = Flatten()(pool1)

input2 = Input(shape=(max_len,))
embedding2 = Embedding(vocab_len, 100)(input1)
conv2 = Conv1D(filters=32, kernel_size=6, activation='relu')(embedding2)
drop2 = Dropout(0.5)(conv2)
pool2 = MaxPool1D(pool_size=2)(drop2)
flat2 = Flatten()(pool2)

input3 = Input(shape=(max_len,))
embedding3 = Embedding(vocab_len, 100)(input3)
conv3 = Conv1D(filters=32, kernel_size=8, activation='relu')(embedding3)
drop3 = Dropout(0.5)(conv3)
pool3 = MaxPool1D(pool_size=2)(drop3)
flat3 = Flatten()(pool3)

input4 = Input(shape=(max_len,))
embedding4 = Embedding(vocab_len, 100)(input4)
conv4 = Conv1D(filters=32, kernel_size=10, activation='relu')(embedding4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPool1D(pool_size=2)(drop4)
flat4 = Flatten()(pool4)

conc = concatenate([flat1, flat2, flat3, flat4])

dens1 = Dense(10, activation='relu')(conc)
output = Dense(1, activation='sigmoid')(dens1)

# %%
model = Model(inputs=[input1, input2, input3, input4], outputs=output)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1693)]       0           []
#
#  input_3 (InputLayer)           [(None, 1693)]       0           []
#
#  input_4 (InputLayer)           [(None, 1693)]       0           []
#
#  embedding (Embedding)          (None, 1693, 100)    4061600     ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, 1693, 100)    4061600     ['input_1[0][0]']
#
#  embedding_2 (Embedding)        (None, 1693, 100)    4061600     ['input_3[0][0]']
#
#  embedding_3 (Embedding)        (None, 1693, 100)    4061600     ['input_4[0][0]']
#
#  conv1d (Conv1D)                (None, 1690, 32)     12832       ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 1688, 32)     19232       ['embedding_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1686, 32)     25632       ['embedding_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 1684, 32)     32032       ['embedding_3[0][0]']
#
#  dropout (Dropout)              (None, 1690, 32)     0           ['conv1d[0][0]']
#
#  dropout_1 (Dropout)            (None, 1688, 32)     0           ['conv1d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 1686, 32)     0           ['conv1d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 1684, 32)     0           ['conv1d_3[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 845, 32)      0           ['dropout[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 844, 32)     0           ['dropout_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 843, 32)     0           ['dropout_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 842, 32)     0           ['dropout_3[0][0]']
#
#  flatten (Flatten)              (None, 27040)        0           ['max_pooling1d[0][0]']
#
#  flatten_1 (Flatten)            (None, 27008)        0           ['max_pooling1d_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 26976)        0           ['max_pooling1d_2[0][0]']
#
#  flatten_3 (Flatten)            (None, 26944)        0           ['max_pooling1d_3[0][0]']
#
#  concatenate (Concatenate)      (None, 107968)       0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]',
#                                                                   'flatten_2[0][0]',
#                                                                   'flatten_3[0][0]']
#
#  dense (Dense)                  (None, 10)           1079690     ['concatenate[0][0]']
#
#  input_2 (InputLayer)           [(None, 1693)]       0           []
#
#  dense_1 (Dense)                (None, 1)            11          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 17,415,829
# Trainable params: 17,415,829
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoded_test = tokenizer.texts_to_sequences(X_test)
padded_test = pad_sequences(encoded_test, maxlen=max_len, padding='post')

# %%
padded_test.shape
# Out:
# (400, 1693)

# %%
model.fit([padded, padded, padded, padded], np.array(y_train), epochs=10, batch_size=20, validation_data=([padded_test, padded_test, padded_test, padded_test], np.array(y_test)))
# Out:
# Epoch 1/10
# 80/80 [==============================] - 43s 517ms/step - loss: 0.6962 - accuracy: 0.4988 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/10
# 80/80 [==============================] - 43s 535ms/step - loss: 0.6912 - accuracy: 0.5000 - val_loss: 0.6867 - val_accuracy: 0.5600
# Epoch 3/10
# 80/80 [==============================] - 46s 575ms/step - loss: 0.5522 - accuracy: 0.7075 - val_loss: 0.5180 - val_accuracy: 0.7600
# Epoch 4/10
# 80/80 [==============================] - 44s 552ms/step - loss: 0.0664 - accuracy: 0.9850 - val_loss: 0.3668 - val_accuracy: 0.8450
# Epoch 5/10
# 80/80 [==============================] - 50s 629ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4092 - val_accuracy: 0.8100
# Epoch 6/10
# 80/80 [==============================] - 49s 611ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3638 - val_accuracy: 0.8500
# Epoch 7/10
# 80/80 [==============================] - 47s 586ms/step - loss: 6.7143e-04 - accuracy: 1.0000 - val_loss: 0.3670 - val_accuracy: 0.8575
# Epoch 8/10
# 80/80 [==============================] - 40s 505ms/step - loss: 4.5741e-04 - accuracy: 1.0000 - val_loss: 0.3663 - val_accuracy: 0.8525
# Epoch 9/10
# 80/80 [==============================] - 43s 538ms/step - loss: 4.3967e-04 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.8525
# Epoch 10/10
# 80/80 [==============================] - 45s 561ms/step - loss: 2.2301e-04 - accuracy: 1.0000 - val_loss: 0.3707 - val_accuracy: 0.8575

# %%
model.save('textcnnMultiChannel.h5')

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('textcnnMultiChannel.h5')

# %%
with open('tokenizer.h5', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
tokenizer.word_index
# Out:
# {'film': 1,
#  'nt': 2,
#  'movie': 3,
#  'one': 4,
#  'like': 5,
#  'even': 6,
#  'good': 7,
#  'time': 8,
#  'would': 9,
#  'story': 10,
#  'much': 11,
#  'character': 12,
#  'also': 13,
#  'get': 14,
#  'characters': 15,
#  'two': 16,
#  'first': 17,
#  'see': 18,
#  'well': 19,
#  'way': 20,
#  'could': 21,
#  'make': 22,
#  'really': 23,
#  'films': 24,
#  'people': 25,
#  'little': 26,
#  'plot': 27,
#  'life': 28,
#  'scene': 29,
#  'bad': 30,
#  'never': 31,
#  'man': 32,
#  'new': 33,
#  'best': 34,
#  'many': 35,
#  'scenes': 36,
#  'know': 37,
#  'movies': 38,
#  'love': 39,
#  'another': 40,
#  'great': 41,
#  'director': 42,
#  'something': 43,
#  'action': 44,
#  'end': 45,
#  'us': 46,
#  'go': 47,
#  'seems': 48,
#  'made': 49,
#  'back': 50,
#  'world': 51,
#  'however': 52,
#  'still': 53,
#  'work': 54,
#  'big': 55,
#  'makes': 56,
#  'every': 57,
#  'audience': 58,
#  'though': 59,
#  'better': 60,
#  'around': 61,
#  'enough': 62,
#  'real': 63,
#  'seen': 64,
#  'take': 65,
#  'performance': 66,
#  'role': 67,
#  'going': 68,
#  'gets': 69,
#  'may': 70,
#  'say': 71,
#  'almost': 72,
#  'think': 73,
#  'last': 74,
#  'actually': 75,
#  'look': 76,
#  'funny': 77,
#  'things': 78,
#  'played': 79,
#  'comedy': 80,
#  'nothing': 81,
#  'although': 82,
#  'years': 83,
#  'thing': 84,
#  'fact': 85,
#  'script': 86,
#  'since': 87,
#  'john': 88,
#  'right': 89,
#  'come': 90,
#  'find': 91,
#  'long': 92,
#  'young': 93,
#  'old': 94,
#  'cast': 95,
#  'plays': 96,
#  'comes': 97,
#  'original': 98,
#  'star': 99,
#  'ever': 100,
#  'show': 101,
#  'least': 102,
#  'lot': 103,
#  'year': 104,
#  'acting': 105,
#  'actors': 106,
#  'without': 107,
#  'part': 108,
#  'quite': 109,
#  'point': 110,
#  'course': 111,
#  'takes': 112,
#  'guy': 113,
#  'goes': 114,
#  'interesting': 115,
#  'ca': 116,
#  'minutes': 117,
#  'away': 118,
#  'screen': 119,
#  'family': 120,
#  'three': 121,
#  'far': 122,
#  'might': 123,
#  'place': 124,
#  'effects': 125,
#  'watch': 126,
#  'rather': 127,
#  'yet': 128,
#  'anything': 129,
#  'day': 130,
#  'must': 131,
#  'seem': 132,
#  'hollywood': 133,
#  'picture': 134,
#  'fun': 135,
#  'bit': 136,
#  'series': 137,
#  'always': 138,
#  'special': 139,
#  'times': 140,
#  'making': 141,
#  'wife': 142,
#  'want': 143,
#  'actor': 144,
#  'give': 145,
#  'kind': 146,
#  'instead': 147,
#  'trying': 148,
#  'set': 149,
#  'woman': 150,
#  'men': 151,
#  'everything': 152,
#  'job': 153,
#  'probably': 154,
#  'becomes': 155,
#  'sense': 156,
#  'american': 157,
#  'given': 158,
#  'home': 159,
#  'dialogue': 160,
#  'along': 161,
#  'sure': 162,
#  'high': 163,
#  'become': 164,
#  'together': 165,
#  'help': 166,
#  'pretty': 167,
#  'everyone': 168,
#  'black': 169,
#  'hard': 170,
#  'whole': 171,
#  'money': 172,
#  'watching': 173,
#  'gives': 174,
#  'got': 175,
#  'father': 176,
#  'especially': 177,
#  'wants': 178,
#  'death': 179,
#  'perhaps': 180,
#  'looking': 181,
#  'feel': 182,
#  'sex': 183,
#  'next': 184,
#  'done': 185,
#  'city': 186,
#  'less': 187,
#  'whose': 188,
#  'moments': 189,
#  'looks': 190,
#  'play': 191,
#  'ending': 192,
#  'horror': 193,
#  'rest': 194,
#  'performances': 195,
#  'james': 196,
#  'music': 197,
#  'different': 198,
#  'anyone': 199,
#  'reason': 200,
#  'completely': 201,
#  'shows': 202,
#  'let': 203,
#  'michael': 204,
#  'simply': 205,
#  'several': 206,
#  'evil': 207,
#  'alien': 208,
#  'night': 209,
#  'couple': 210,
#  'entire': 211,
#  'mind': 212,
#  '2': 213,
#  'put': 214,
#  'human': 215,
#  'humor': 216,
#  'getting': 217,
#  'left': 218,
#  'turns': 219,
#  'line': 220,
#  'someone': 221,
#  'girl': 222,
#  'problem': 223,
#  'use': 224,
#  'friend': 225,
#  'begins': 226,
#  'either': 227,
#  'main': 228,
#  'found': 229,
#  'unfortunately': 230,
#  'true': 231,
#  'lost': 232,
#  'small': 233,
#  'half': 234,
#  'idea': 235,
#  'final': 236,
#  'case': 237,
#  'tries': 238,
#  'friends': 239,
#  'else': 240,
#  'group': 241,
#  'stars': 242,
#  'tv': 243,
#  'used': 244,
#  'wrong': 245,
#  'believe': 246,
#  'house': 247,
#  'later': 248,
#  'name': 249,
#  'written': 250,
#  'called': 251,
#  'mother': 252,
#  'thought': 253,
#  'certainly': 254,
#  'soon': 255,
#  'comic': 256,
#  'david': 257,
#  'said': 258,
#  'sequence': 259,
#  'town': 260,
#  'often': 261,
#  'maybe': 262,
#  'named': 263,
#  'school': 264,
#  'finally': 265,
#  'relationship': 266,
#  'playing': 267,
#  'able': 268,
#  'head': 269,
#  'hand': 270,
#  'keep': 271,
#  'perfect': 272,
#  'based': 273,
#  'works': 274,
#  'summer': 275,
#  'second': 276,
#  'turn': 277,
#  'past': 278,
#  'despite': 279,
#  'including': 280,
#  'dark': 281,
#  'seeing': 282,
#  'behind': 283,
#  'dead': 284,
#  'book': 285,
#  'run': 286,
#  'fight': 287,
#  'finds': 288,
#  'car': 289,
#  'supposed': 290,
#  'lives': 291,
#  'tell': 292,
#  'days': 293,
#  'running': 294,
#  'directed': 295,
#  'person': 296,
#  'moment': 297,
#  'need': 298,
#  'lines': 299,
#  'game': 300,
#  'children': 301,
#  'entertaining': 302,
#  'camera': 303,
#  'shot': 304,
#  'kids': 305,
#  'nice': 306,
#  'side': 307,
#  'try': 308,
#  'war': 309,
#  'worth': 310,
#  'live': 311,
#  'start': 312,
#  'boy': 313,
#  'major': 314,
#  'full': 315,
#  'hour': 316,
#  'mr': 317,
#  'matter': 318,
#  'starts': 319,
#  'joe': 320,
#  'face': 321,
#  'earth': 322,
#  'worst': 323,
#  'son': 324,
#  'team': 325,
#  'exactly': 326,
#  'style': 327,
#  'problems': 328,
#  'version': 329,
#  'scream': 330,
#  'daughter': 331,
#  'example': 332,
#  'order': 333,
#  'care': 334,
#  'nearly': 335,
#  'sequences': 336,
#  'kevin': 337,
#  'others': 338,
#  'screenplay': 339,
#  'violence': 340,
#  'review': 341,
#  'beautiful': 342,
#  'upon': 343,
#  'throughout': 344,
#  'space': 345,
#  'short': 346,
#  'video': 347,
#  'fine': 348,
#  'early': 349,
#  'simple': 350,
#  'drama': 351,
#  'known': 352,
#  'already': 353,
#  'direction': 354,
#  'title': 355,
#  'opening': 356,
#  'kill': 357,
#  'robert': 358,
#  'jackie': 359,
#  'hit': 360,
#  'act': 361,
#  'knows': 362,
#  'white': 363,
#  'top': 364,
#  'jack': 365,
#  'production': 366,
#  'obvious': 367,
#  'peter': 368,
#  'planet': 369,
#  'sort': 370,
#  'save': 371,
#  'saw': 372,
#  'classic': 373,
#  'women': 374,
#  'lee': 375,
#  'jokes': 376,
#  'york': 377,
#  'boring': 378,
#  'beginning': 379,
#  'roles': 380,
#  'guys': 381,
#  'deep': 382,
#  'killer': 383,
#  'eyes': 384,
#  'room': 385,
#  'truly': 386,
#  'body': 387,
#  'attempt': 388,
#  'disney': 389,
#  'supporting': 390,
#  'sometimes': 391,
#  'ends': 392,
#  'wonder': 393,
#  'lead': 394,
#  'stupid': 395,
#  'possible': 396,
#  'child': 397,
#  'extremely': 398,
#  'strong': 399,
#  'heart': 400,
#  'wo': 401,
#  'says': 402,
#  'coming': 403,
#  'brother': 404,
#  'ship': 405,
#  'involving': 406,
#  'worse': 407,
#  'level': 408,
#  'voice': 409,
#  'mostly': 410,
#  'genre': 411,
#  'yes': 412,
#  'particularly': 413,
#  'happens': 414,
#  'question': 415,
#  'police': 416,
#  'aliens': 417,
#  'tom': 418,
#  'novel': 419,
#  'eventually': 420,
#  'tells': 421,
#  'husband': 422,
#  'falls': 423,
#  'girls': 424,
#  'four': 425,
#  'manages': 426,
#  'quickly': 427,
#  'hours': 428,
#  'career': 429,
#  'future': 430,
#  'emotional': 431,
#  'meet': 432,
#  'sets': 433,
#  'power': 434,
#  'five': 435,
#  'hero': 436,
#  'sound': 437,
#  'appears': 438,
#  'romantic': 439,
#  'involved': 440,
#  'fall': 441,
#  'murder': 442,
#  'close': 443,
#  'lack': 444,
#  'hope': 445,
#  'stop': 446,
#  'piece': 447,
#  'none': 448,
#  'leads': 449,
#  'note': 450,
#  'dog': 451,
#  'guess': 452,
#  'mission': 453,
#  'result': 454,
#  'material': 455,
#  'mean': 456,
#  'elements': 457,
#  'thriller': 458,
#  'dr': 459,
#  'chance': 460,
#  'taken': 461,
#  'smith': 462,
#  'enjoy': 463,
#  'taking': 464,
#  'hell': 465,
#  'usually': 466,
#  'obviously': 467,
#  'laughs': 468,
#  'television': 469,
#  'forced': 470,
#  'among': 471,
#  'computer': 472,
#  'needs': 473,
#  'paul': 474,
#  'killed': 475,
#  '1': 476,
#  'george': 477,
#  'god': 478,
#  'de': 479,
#  'attention': 480,
#  'history': 481,
#  'interest': 482,
#  'living': 483,
#  'talk': 484,
#  'number': 485,
#  'feeling': 486,
#  'king': 487,
#  'fans': 488,
#  'seemed': 489,
#  'laugh': 490,
#  'basically': 491,
#  'deal': 492,
#  'single': 493,
#  'talent': 494,
#  'except': 495,
#  'oscar': 496,
#  'easy': 497,
#  'science': 498,
#  'experience': 499,
#  'word': 500,
#  'late': 501,
#  'poor': 502,
#  'bring': 503,
#  'theater': 504,
#  'impressive': 505,
#  'viewer': 506,
#  'features': 507,
#  'success': 508,
#  'attempts': 509,
#  'feels': 510,
#  'tale': 511,
#  'fiction': 512,
#  'cool': 513,
#  'robin': 514,
#  'chris': 515,
#  'whether': 516,
#  'america': 517,
#  'words': 518,
#  'battle': 519,
#  'girlfriend': 520,
#  'crew': 521,
#  'within': 522,
#  'sequel': 523,
#  'release': 524,
#  'recent': 525,
#  'premise': 526,
#  'apparently': 527,
#  'across': 528,
#  'somehow': 529,
#  'entertainment': 530,
#  'using': 531,
#  'leave': 532,
#  'easily': 533,
#  'feature': 534,
#  'batman': 535,
#  'score': 536,
#  'wild': 537,
#  'told': 538,
#  'happen': 539,
#  'went': 540,
#  'crime': 541,
#  'form': 542,
#  'stuff': 543,
#  'wonderful': 544,
#  'alone': 545,
#  'surprise': 546,
#  '3': 547,
#  'serious': 548,
#  'important': 549,
#  'expect': 550,
#  'released': 551,
#  'van': 552,
#  'presence': 553,
#  'parents': 554,
#  'call': 555,
#  'ways': 556,
#  'williams': 557,
#  'giving': 558,
#  'working': 559,
#  'ben': 560,
#  'events': 561,
#  'happy': 562,
#  'former': 563,
#  'art': 564,
#  'return': 565,
#  'complete': 566,
#  'change': 567,
#  'meets': 568,
#  'popular': 569,
#  'difficult': 570,
#  'certain': 571,
#  'general': 572,
#  'parts': 573,
#  'hilarious': 574,
#  'william': 575,
#  'brothers': 576,
#  'brings': 577,
#  'oh': 578,
#  'quality': 579,
#  'turned': 580,
#  'figure': 581,
#  'kid': 582,
#  'reality': 583,
#  'suspense': 584,
#  'effective': 585,
#  'sexual': 586,
#  'annoying': 587,
#  'flick': 588,
#  'previous': 589,
#  'wars': 590,
#  'ago': 591,
#  'middle': 592,
#  'decides': 593,
#  'bill': 594,
#  'personal': 595,
#  'business': 596,
#  'carter': 597,
#  'strange': 598,
#  'familiar': 599,
#  'credits': 600,
#  'similar': 601,
#  'uses': 602,
#  'anyway': 603,
#  'remember': 604,
#  'project': 605,
#  'company': 606,
#  'gone': 607,
#  'surprisingly': 608,
#  'intelligent': 609,
#  'blood': 610,
#  'came': 611,
#  'jim': 612,
#  'filmmakers': 613,
#  'runs': 614,
#  'somewhat': 615,
#  '4': 616,
#  'powerful': 617,
#  'local': 618,
#  'present': 619,
#  'opens': 620,
#  'writer': 621,
#  'towards': 622,
#  'shots': 623,
#  'villain': 624,
#  'dramatic': 625,
#  'visual': 626,
#  'die': 627,
#  'situation': 628,
#  'questions': 629,
#  'definitely': 630,
#  'harry': 631,
#  'potential': 632,
#  'usual': 633,
#  'party': 634,
#  'murphy': 635,
#  'ones': 636,
#  'jones': 637,
#  'light': 638,
#  'successful': 639,
#  'writing': 640,
#  'third': 641,
#  'seriously': 642,
#  'mystery': 643,
#  'romance': 644,
#  'sam': 645,
#  'due': 646,
#  'trek': 647,
#  'begin': 648,
#  'secret': 649,
#  'cut': 650,
#  'felt': 651,
#  'leaving': 652,
#  'clear': 653,
#  'beyond': 654,
#  'cop': 655,
#  'nature': 656,
#  'office': 657,
#  'leaves': 658,
#  'bunch': 659,
#  'smart': 660,
#  'took': 661,
#  'cameron': 662,
#  'type': 663,
#  'read': 664,
#  'prison': 665,
#  'martin': 666,
#  'absolutely': 667,
#  'doubt': 668,
#  'richard': 669,
#  'escape': 670,
#  'huge': 671,
#  'subject': 672,
#  'unlike': 673,
#  'add': 674,
#  'latest': 675,
#  'straight': 676,
#  'following': 677,
#  'decent': 678,
#  'rich': 679,
#  'starring': 680,
#  'scott': 681,
#  'means': 682,
#  'mars': 683,
#  'allen': 684,
#  'large': 685,
#  'scary': 686,
#  'excellent': 687,
#  'effect': 688,
#  'ryan': 689,
#  'actress': 690,
#  'talking': 691,
#  'plan': 692,
#  'heard': 693,
#  'inside': 694,
#  'thinking': 695,
#  'follow': 696,
#  '10': 697,
#  'brilliant': 698,
#  'mess': 699,
#  'near': 700,
#  'cinema': 701,
#  'create': 702,
#  'follows': 703,
#  'move': 704,
#  'overall': 705,
#  'clever': 706,
#  'amazing': 707,
#  'motion': 708,
#  'impossible': 709,
#  'chase': 710,
#  'saying': 711,
#  'message': 712,
#  'force': 713,
#  'created': 714,
#  'chan': 715,
#  'giant': 716,
#  'break': 717,
#  'stay': 718,
#  'country': 719,
#  'audiences': 720,
#  'million': 721,
#  'trouble': 722,
#  'learn': 723,
#  'married': 724,
#  'realize': 725,
#  'water': 726,
#  'godzilla': 727,
#  'liked': 728,
#  'age': 729,
#  'ultimately': 730,
#  'eddie': 731,
#  'moving': 732,
#  'viewers': 733,
#  'park': 734,
#  'points': 735,
#  'bob': 736,
#  'agent': 737,
#  'bruce': 738,
#  'understand': 739,
#  'predictable': 740,
#  'merely': 741,
#  'fails': 742,
#  'west': 743,
#  'appear': 744,
#  'filled': 745,
#  'favorite': 746,
#  'master': 747,
#  'enjoyable': 748,
#  'happened': 749,
#  'immediately': 750,
#  'wanted': 751,
#  'exciting': 752,
#  'dream': 753,
#  'otherwise': 754,
#  'pay': 755,
#  'slow': 756,
#  'r': 757,
#  'situations': 758,
#  'simon': 759,
#  'stories': 760,
#  'brought': 761,
#  'fan': 762,
#  'offers': 763,
#  'frank': 764,
#  'neither': 765,
#  'likely': 766,
#  'showing': 767,
#  'tim': 768,
#  'ideas': 769,
#  'solid': 770,
#  'memorable': 771,
#  'atmosphere': 772,
#  'english': 773,
#  'ten': 774,
#  'actual': 775,
#  'dumb': 776,
#  'studio': 777,
#  'mark': 778,
#  'government': 779,
#  'constantly': 780,
#  'perfectly': 781,
#  'l': 782,
#  'stone': 783,
#  'e': 784,
#  'political': 785,
#  'animated': 786,
#  'particular': 787,
#  'biggest': 788,
#  'control': 789,
#  'effort': 790,
#  'credit': 791,
#  'state': 792,
#  'entirely': 793,
#  'purpose': 794,
#  'mary': 795,
#  'red': 796,
#  'various': 797,
#  'typical': 798,
#  'spend': 799,
#  'aspect': 800,
#  'cold': 801,
#  'silly': 802,
#  'bond': 803,
#  'army': 804,
#  'humans': 805,
#  'truth': 806,
#  'musical': 807,
#  'gave': 808,
#  'today': 809,
#  'woody': 810,
#  'law': 811,
#  'spent': 812,
#  'nick': 813,
#  'truman': 814,
#  'fear': 815,
#  'tension': 816,
#  'suddenly': 817,
#  'earlier': 818,
#  'slightly': 819,
#  'focus': 820,
#  'hands': 821,
#  'rating': 822,
#  'ii': 823,
#  'ask': 824,
#  'open': 825,
#  'element': 826,
#  'max': 827,
#  'wedding': 828,
#  'society': 829,
#  'british': 830,
#  'totally': 831,
#  'indeed': 832,
#  'subplot': 833,
#  'view': 834,
#  'sit': 835,
#  'ability': 836,
#  'complex': 837,
#  'whatever': 838,
#  'members': 839,
#  'killing': 840,
#  'queen': 841,
#  'cinematography': 842,
#  'setting': 843,
#  'class': 844,
#  'box': 845,
#  'female': 846,
#  'jerry': 847,
#  'convincing': 848,
#  'dull': 849,
#  'amusing': 850,
#  'moves': 851,
#  'fast': 852,
#  'greatest': 853,
#  'wait': 854,
#  'animation': 855,
#  'waste': 856,
#  'terrible': 857,
#  'college': 858,
#  'miss': 859,
#  'carry': 860,
#  'lots': 861,
#  'private': 862,
#  'steve': 863,
#  'background': 864,
#  'steven': 865,
#  'approach': 866,
#  'eye': 867,
#  'leader': 868,
#  'beauty': 869,
#  'mike': 870,
#  'soundtrack': 871,
#  'free': 872,
#  'subtle': 873,
#  'recently': 874,
#  'sweet': 875,
#  'decide': 876,
#  'monster': 877,
#  'titanic': 878,
#  'hold': 879,
#  'expected': 880,
#  'appearance': 881,
#  'fairly': 882,
#  'shown': 883,
#  'drug': 884,
#  'chemistry': 885,
#  'carrey': 886,
#  'stand': 887,
#  'thinks': 888,
#  'awful': 889,
#  'cheap': 890,
#  'joke': 891,
#  'hate': 892,
#  'list': 893,
#  'minor': 894,
#  'language': 895,
#  'reasons': 896,
#  'common': 897,
#  'flat': 898,
#  'casting': 899,
#  'plenty': 900,
#  'keeps': 901,
#  'cinematic': 902,
#  'theme': 903,
#  'depth': 904,
#  'club': 905,
#  'talented': 906,
#  'ridiculous': 907,
#  'teen': 908,
#  'air': 909,
#  'images': 910,
#  'longer': 911,
#  'partner': 912,
#  'screenwriter': 913,
#  'tone': 914,
#  'race': 915,
#  'front': 916,
#  'believable': 917,
#  'asks': 918,
#  'rock': 919,
#  'outside': 920,
#  'wish': 921,
#  'wrote': 922,
#  'baby': 923,
#  'gun': 924,
#  'violent': 925,
#  'okay': 926,
#  'president': 927,
#  'french': 928,
#  'sister': 929,
#  'incredibly': 930,
#  'budget': 931,
#  'stands': 932,
#  'scifi': 933,
#  'key': 934,
#  'remains': 935,
#  'clearly': 936,
#  'development': 937,
#  'brief': 938,
#  'j': 939,
#  'energy': 940,
#  'sight': 941,
#  'event': 942,
#  'disaster': 943,
#  'charm': 944,
#  'somewhere': 945,
#  'member': 946,
#  'sounds': 947,
#  'meanwhile': 948,
#  'conclusion': 949,
#  'island': 950,
#  'la': 951,
#  'amount': 952,
#  'pull': 953,
#  'willis': 954,
#  'sean': 955,
#  'knew': 956,
#  'imagine': 957,
#  'fire': 958,
#  'grace': 959,
#  'b': 960,
#  'onto': 961,
#  'detective': 962,
#  'writers': 963,
#  'choice': 964,
#  'boss': 965,
#  'dreams': 966,
#  'opportunity': 967,
#  'minute': 968,
#  'jackson': 969,
#  'caught': 970,
#  'provide': 971,
#  'trailer': 972,
#  'thus': 973,
#  'critics': 974,
#  'blade': 975,
#  'realistic': 976,
#  'boys': 977,
#  'led': 978,
#  'modern': 979,
#  'possibly': 980,
#  '1998': 981,
#  'song': 982,
#  'basic': 983,
#  'provides': 984,
#  'vampire': 985,
#  'worked': 986,
#  'road': 987,
#  'ride': 988,
#  'fox': 989,
#  'telling': 990,
#  'consider': 991,
#  'puts': 992,
#  'six': 993,
#  'seemingly': 994,
#  'contains': 995,
#  'etc': 996,
#  'hear': 997,
#  'famous': 998,
#  'pace': 999,
#  'tough': 1000,
#  ...}

# %%
txt = '''
boy , what a great movie ! ! 
keanu reeves and morgan freeman acting together , the director of the fugitive ( andrew davis ) back again to give us another thriller , and the beautiful rachel stealing beauty weisz thrown in to boot . 
how could this not be a blockbuster ? 
all die-hard keanu reeves fans , read on . 
ol " much ado about nothing " plays eddie kasalivich , a machinist studying at the university of chicago . 
to help pay for the rent , he takes on this job making the machinery for a hydrogen project being conducted by the university . 
by happy coincidence , he also happens to stumble on the solution to the final problem and thus is the only one who knows the key to performing this feat of miracle physics . 
this project holds great promise : taking hydrogen from water and giving out more energy than is put in . 
a potential solution to the earth's energy problems without the pollution cost . 
surely nobody could have any problems with that ? 
morgan freeman is paul shannon , the project's sponsor . 
he works for a very powerful organization that disagrees with the paternal project leader as to how quickly technology should be released to the public . 
he figures the world will disintegrate into anarchy if the results of the project are released too quickly . 
so he murders the project leader , blows up the project ( great but short scene here , sort of like a mini id4 city-devastation thing ) and tries to simulate the experiment at some other hi-tech hush-hush location . 
unfortunately , our intrepid machinist and an english physicist ( weisz ) manage to get away and now follows a fugitive-like chase using a not too dissimilar rehash of that movie script . 
this movie is just dying for a comparison with " the fugitive " . 
both movies use chicago as the main city and since the place doesn't change much , i guess we can't really blame the setting for the paucity of atmosphere . 
the trouble here is that where the fugitive had harrison ford and tommy lee jones , chain reaction only has keanu reeves and fred ward . 
credit to them , but we aren't really given much of a chance to empathise with the characters . 
where ford was able to work within the confines of the movie to evoke sympathy , eddie kasalivich just doesn9t seem very believeable and reeves' character is never given the time to develop . 
it might have been a better investment in film to give the characters more depth and spend less time on the chase sequences , which frankly , get quite boring after a while . 
harrison ford was " the man against the world . " 
he was alone in a world where he didn't know who to trust and it came across real well . 
in chain reaction , keanu reeves isn't alone . 
now that would be fine if the fleeing couple had some chemistry and could really portray some paranoia , vulnerability and confusion . 
we don't get this . 
we get him thinking he's still in speed , only now our sandra bullock has an english accent , probably doesn't drive a bus , and hardly contributes anything to the movie . 
the producers here probably thought , " hey , what if keanu and rachel don't hit it off too well ? 
let's rope in that morgan to help us out . " 
well , keanu and rachel didn't hit it off well on the screen , and most unfortunately , morgan freeman doesn't help much either . 
the only thing we come to really know of paul shannon is that he always has a full load of cigars in his cigar holder . 
it's not really his fault . 
once again , andrew davis just doesn't take the time to build his characters . 
someone must have convinced him that this time round , cinema dollars are best earned by making the movie run like a headless chicken . 
the flying inkpot rating system : * wait for the tv2 broadcast . 
 * * a little creaky , but still better than staying at home with gotcha ! 
 * * * pretty good , bring a friend . 
 * * * * amazing , potent stuff . 
 * * * * * perfection . 
see it twice . 
'''

# %%
encoded_doc = tokenizer.texts_to_sequences([txt])

# %%
padded_doc = pad_sequences(encoded_doc, maxlen=max_len, padding='post')

# %%
padded_doc
# Out:
# array([[313,  41,   3, ...,   0,   0,   0]])

# %%
model.predict([padded_doc, padded_doc, padded_doc, padded_doc])[0][0]
# Out:
# 1/1 [==============================] - 0s 180ms/step
# 0.01420637

# %%
if model.predict([padded_doc, padded_doc, padded_doc, padded_doc])[0][0] < 0.5:
    print('Negative')
else:
    print('Positive')
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Negative
