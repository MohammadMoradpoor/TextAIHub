# %%
import requests
from lxml import html

# %%
page = requests.get('https://ganjoor.net/khayyam/robaee/sh1/')

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="fa-IR" dir="rtl">\r\n<head>\r\n    <meta charset="utf-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\r\n    <title>\r\n        \xda\xaf\xd9\x86\xd8\xac\xd9\x88\xd8\xb1 \xc2\xbb \xd8\xae\xdb\x8c\xd8\xa7\xd9\x85 \xc2\xbb \xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c\xd8\xa7\xd8\xaa \xc2\xbb \xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c \xd8\xb4\xd9\x85\xd8\xa7\xd8\xb1\xd9\x87\xd9\x94 \xdb\xb1\r\n    </title>\r\n    <link href="/css/p8.css?version=51" rel="stylesheet" type="text/css" />\r\n    <link rel="shortcut icon" href="/favicon.ico?version=1" type="image/x-icon" />\r\n    <link rel="search" type="application/opensearchdescription+xml" title="\xda\xaf\xd9\x86\xd8\xac\xd9\x88\xd8\xb1" href="https://ganjoor.net/search.xml" />\r\n    <script src="/lib/jquery/dist/jquery.min.js"></script>\r\n    <script src="/js/bk.js?version=35"></script>\r\n    <script>\r\n        var cookieValue = getCookie("playerScrollLock");\r\n        var playerScrollLock = cookieValue === "true";\r\n\r\n        cookieValue = getCookie("stickyEnabled");\r\n        var stickyEnabled = cookieValue != "false";\r\n\r\n        cookieValue = getCookie("lineNumbers");\r\n        var lineNumbers = cookieValue != "false";\r\n    </script>\r\n\r\n\r\n        <link rel="canonical" href="https://ganjoor.net/khayyam/robaee/sh1" />\r\n            <script>\r\n                $(document).ready(function() {\r\n                    checkWebShareSupport();\r\n                    if (lineNumbers) {\r\n                        btshmr(1119);\r\n                    }\r\n                    checkIfBookmarked(1119);\r\n                });\r\n            </script>\r\n        <script type="application/ld+json">\r\n            {\r\n             "@context": "http://schema.org",\r\n "@type": "BreadcrumbList",\r\n "itemListElement": [\r\n     {\r\n     "@type": "ListItem",\r\n     "position": 1,\r\n     "item": {\r\n         "@id": "https://ganjoor.net/khayyam/",\r\n         "name": "\xd8\xae\xdb\x8c\xd8\xa7\xd9\x85", \r\n         "image": "https://api.ganjoor.net/api/ganjoor/poet/image/khayyam.gif"\r\n     }\r\n    },\r\n     {\r\n     "@type": "ListItem",\r\n     "position": 2,\r\n     "item": {\r\n         "@id": "https://ganjoor.net/khayyam/robaee/",\r\n         "name": "\xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c\xd8\xa7\xd8\xaa", \r\n         "image": "https://i.ganjoor.net/cat.png"\r\n     }\r\n    },\r\n     {\r\n     "@type": "ListItem",\r\n     "position": 3,\r\n     "item": {\r\n         "@id": "https://ganjoor.net/khayyam/robaee/sh1/",\r\n         "name": "\xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c \xd8\xb4\xd9\x85\xd8\xa7\xd8\xb1\xd9\x87\xd9\x94 \xdb\xb1", \r\n         "image": "https://i.ganjoor.net/poem.png"\r\n     }\r\n    }\r\n]\r\n\r\n            }\r\n        </script>\r\n\r\n\r\n\r\n</head>\r\n<body>\r\n    <script src="/js/vaabd.js?version=2"></script>\r\n\r\n            <script>\r\n                var currentAudio = null;\r\n                var verseStart = [];\r\n                var verseEnd = [];\r\n                var verseIndex = [];\r\n                var nLastHighlight = -1;\r\n                var vCount = 0;\r\n\r\n                var _setXml = function(xmlUrl) {\r\n                    $.ajax({\r\n                        type: "GET",\r\n                        url: xmlUrl,\r\n                        dataType: "xml",\r\n                        success: function(xml) {\r\n                            var nOneSecondBugFix = 2000;\r\n                            $(xml).find(\'OneSecondBugFix\').each(function() {\r\n                                nOneSecondBugFix = parseInt($(xml).find(\'OneSecondBugFix\').text());\r\n                            });\r\n                            var v = 0;\r\n                            $(xml).find(\'SyncInfo\').each(function() {\r\n                                verseStart[v] = parseInt($(this).find(\'AudioMiliseconds\').text()) / nOneSecondBugFix;\r\n                    ...

# %%
tree = html.fromstring(page.content)

# %%
tree
# Out:
# <Element html at 0x1a282e0cf40>

# %%
tree.xpath('//div[@class="b"]/div/p/text()')
# Out:
# ['برخیز بتا بیا ز بهر دل ما',
#  'حل کن به جمال خویشتن مشکل ما',
#  'یک کوزه شراب تا به هم نوش کنیم',
#  'زآن پیش که کوزه\u200cها کنند از گل ما']

# %%
for i in range(1, 179):
    page = requests.get('https://ganjoor.net/khayyam/robaee/sh' + str(i) + '/')
    tree = html.fromstring(page.content)
    with open('khayaam.txt', 'a', encoding="utf-8") as f:
        for t in tree.xpath('//div[@class="b"]/div/p/text()'):
            f.write('|' + str(t.replace('\u200c', ' ')) + '\n')
